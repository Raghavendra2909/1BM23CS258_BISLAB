# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import random
from pathlib import Path
from IPython.display import display, HTML

# %%
# PARAMETERS (edit these before running)
NUM_POINTS = 12           # number of delivery locations (excluding depot)
FIELD_SIZE = 100          # coordinate range (0..FIELD_SIZE)
NUM_NESTS = 40            # population of nests (solutions)
MAX_ITER = 200            # number of iterations
PA = 0.25                 # fraction of nests to abandon each generation
ALPHA = 0.01              # step size multiplier for Lévy flights (exploration scale)
BETA = 1.5                # Lévy exponent (1 < beta <= 2). Commonly 1.5 or 1.8
DRONE_MAX_LEG = 60.0      # maximum allowed leg distance before strong penalty
RANDOM_SEED = 42
SAVE_DIR = Path("/mnt/data")  # adjust or leave default for local Jupyter

np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# Print quick explanation of important parameters
print("EXPLANATION:")
print(f"- alpha (ALPHA) : step size multiplier that scales the Lévy flight steps. Larger alpha -> bigger jumps (more exploration). Here ALPHA = {ALPHA}.")
print(f"- beta (BETA) : Lévy exponent controlling the heavy-tailed distribution of step sizes. 1 < beta <= 2. Here BETA = {BETA}.")

# %%
# Problem setup: depot + delivery points
# You can either generate random points or load your own coordinates (see optional cell below)

def generate_random_problem(num_points=NUM_POINTS, field_size=FIELD_SIZE):
    depot = np.array([field_size/2, field_size/2])  # depot at center by default
    points = np.random.rand(num_points, 2) * field_size
    all_points = np.vstack([depot, points])  # index 0 is depot
    return all_points

all_points = generate_random_problem()
print(f"Generated {len(all_points)-1} delivery points + 1 depot. Depot at index 0.")

# Optional: display the points as a small table
points_df = pd.DataFrame(all_points, columns=["x","y"]) 
points_df.index.name = 'index'
display(points_df)


def route_from_key(key):
    """Random-key encoding: key is continuous vector of length NUM_POINTS; argsort gives permutation."""
    indices = np.argsort(key)
    route = [0] + (indices + 1).tolist() + [0]
    return route


def route_distance(route, points=all_points):
    coords = points[np.array(route)]
    dists = np.sqrt(((coords[1:] - coords[:-1])**2).sum(axis=1))
    return dists.sum(), dists


def objective_from_key(key, points=all_points, drone_max_leg=DRONE_MAX_LEG):
    route = route_from_key(key)
    total, dists = route_distance(route, points=points)
    penalty = 0.0
    over = dists - drone_max_leg
    if np.any(over > 0):
        penalty = 1e3 * (over[over>0]**2).sum()
    return total + penalty

# %%
# Lévy flight using Mantegna's algorithm

def levy_flight(beta, dim):
    """Return a vector of steps drawn from a Lévy distribution using Mantegna's algorithm."""
    # stability factor sigma_u
    sigma_u = (math.gamma(1+beta) * math.sin(math.pi*beta/2) / 
               (math.gamma((1+beta)/2) * beta * 2**((beta-1)/2))) ** (1/beta)
    u = np.random.normal(0, sigma_u, size=dim)
    v = np.random.normal(0, 1, size=dim)
    step = u / (np.abs(v) ** (1.0/beta))
    return step

# %%
# Cuckoo Search core loop

dim = all_points.shape[0] - 1  # number of deliveries
nests = np.random.rand(NUM_NESTS, dim)
fitness = np.array([objective_from_key(nests[i]) for i in range(NUM_NESTS)])
best_idx = np.argmin(fitness)
best_nest = nests[best_idx].copy()
best_fitness = fitness[best_idx]

history = []
print(f"Initial best fitness: {best_fitness:.6f}")
history.append({"iter": 0, "best_fitness": float(best_fitness), "mean_fitness": float(fitness.mean())})

for it in range(1, MAX_ITER+1):
    # Lévy flight updates
    for i in range(NUM_NESTS):
        current = nests[i].copy()
        step = levy_flight(BETA, dim)
        new_solution = current + ALPHA * step * (current - best_nest)
        new_solution = np.mod(new_solution, 1.0)
        new_fitness = objective_from_key(new_solution)
        if new_fitness < fitness[i]:
            nests[i] = new_solution
            fitness[i] = new_fitness

    # Abandon worst PA fraction
    K = int(PA * NUM_NESTS)
    if K > 0:
        worst_idx = np.argsort(fitness)[-K:]
        for idx in worst_idx:
            nests[idx] = np.random.rand(dim)
            fitness[idx] = objective_from_key(nests[idx])

    # Update global best
    cur_best_idx = np.argmin(fitness)
    cur_best_fitness = fitness[cur_best_idx]
    if cur_best_fitness < best_fitness:
        best_fitness = cur_best_fitness
        best_nest = nests[cur_best_idx].copy()

    history.append({"iter": it, "best_fitness": float(best_fitness), "mean_fitness": float(fitness.mean())})

    # Print iteration summary (every iteration)
    route = route_from_key(best_nest)
    if it % 1 == 0:
        print(f"Iter {it:3d} | Best fitness: {best_fitness:10.4f} | Mean fitness: {fitness.mean():10.4f}")

# %%
# Results, save history and plot
history_df = pd.DataFrame(history)
SAVE_DIR.mkdir(parents=True, exist_ok=True)
csv_path = SAVE_DIR / 'iteration_history.csv'
plot_path = SAVE_DIR / 'convergence.png'
history_df.to_csv(csv_path, index=False)

print("\nFINAL BEST ROUTE AND METRICS")
best_route = route_from_key(best_nest)
best_total, best_leg_distances = route_distance(best_route)
print(f"Best fitness (with penalties): {best_fitness:.6f}")
print(f"Best route (indices w.r.t all_points where 0 is depot): {best_route}")
print(f"Total route distance (no penalties): {best_total:.6f}")
print(f"Per-leg distances: {np.round(best_leg_distances,3).tolist()}")
# Out:
# EXPLANATION:
# - alpha (ALPHA) : step size multiplier that scales the Lévy flight steps. Larger alpha -> bigger jumps (more exploration). Here ALPHA = 0.01.
# - beta (BETA) : Lévy exponent controlling the heavy-tailed distribution of step sizes. 1 < beta <= 2. Here BETA = 1.5.
# Generated 12 delivery points + 1 depot. Depot at index 0.
#                x          y
# index
# 0      50.000000  50.000000
# 1      37.454012  95.071431
# 2      73.199394  59.865848
# 3      15.601864  15.599452
# 4       5.808361  86.617615
# 5      60.111501  70.807258
# 6       2.058449  96.990985
# 7      83.244264  21.233911
# 8      18.182497  18.340451
# 9      30.424224  52.475643
# 10     43.194502  29.122914
# 11     61.185289  13.949386
# 12     29.214465  36.636184
# Initial best fitness: 347963.970606
# Iter   1 | Best fitness: 175404.1126 | Mean fitness: 1592798.3401
# Iter   2 | Best fitness: 28670.1060 | Mean fitness: 1132628.6532
# Iter   3 | Best fitness: 28670.1060 | Mean fitness: 1310212.0898
# Iter   4 | Best fitness: 28670.1060 | Mean fitness: 977041.7139
# Iter   5 | Best fitness: 28670.1060 | Mean fitness: 1094044.9271
# Iter   6 | Best fitness: 28670.1060 | Mean fitness: 1204544.6585
# Iter   7 | Best fitness: 28670.1060 | Mean fitness: 1286864.0984
# Iter   8 | Best fitness: 28670.1060 | Mean fitness: 821965.2945
# Iter   9 | Best fitness: 28670.1060 | Mean fitness: 945467.4046
# Iter  10 | Best fitness: 28670.1060 | Mean fitness: 920619.0321
# Iter  11 | Best fitness: 28670.1060 | Mean fitness: 745006.3869
# Iter  12 | Best fitness: 28670.1060 | Mean fitness: 917378.1481
# Iter  13 | Best fitness: 28670.1060 | Mean fitness: 615047.4237
# Iter  14 | Best fitness: 28670.1060 | Mean fitness: 913245.2005
# Iter  15 | Best fitness: 28670.1060 | Mean fitness: 822152.0712
# Iter  16 | Best fitness: 14160.9460 | Mean fitness: 767021.4530
# Iter  17 | Best fitness: 14160.9460 | Mean fitness: 648363.7445
# Iter  18 | Best fitness: 14160.9460 | Mean fitness: 839805.8474
# Iter  19 | Best fitness: 14160.9460 | Mean fitness: 737006.5650
# Iter  20 | Best fitness: 14160.9460 | Mean fitness: 677345.0538
# Iter  21 | Best fitness: 14160.9460 | Mean fitness: 641881.7544
# Iter  22 | Best fitness: 14160.9460 | Mean fitness: 714999.2494
# Iter  23 | Best fitness: 14160.9460 | Mean fitness: 662485.0581
# Iter  24 | Best fitness: 14160.9460 | Mean fitness: 641089.0013
# Iter  25 | Best fitness: 14160.9460 | Mean fitness: 644501.5305
# Iter  26 | Best fitness: 14160.9460 | Mean fitness: 616067.0550
# Iter  27 | Best fitness: 14160.9460 | Mean fitness: 718045.4016
# Iter  28 | Best fitness: 14160.9460 | Mean fitness: 634984.0763
# Iter  29 | Best fitness: 14160.9460 | Mean fitness: 519747.1920
# Iter  30 | Best fitness: 14160.9460 | Mean fitness: 656362.4512
# Iter  31 | Best fitness: 14160.9460 | Mean fitness: 727051.7081
# Iter  32 | Best fitness: 14160.9460 | Mean fitness: 652074.2243
# Iter  33 | Best fitness: 14160.9460 | Mean fitness: 736681.7582
# Iter  34 | Best fitness: 14160.9460 | Mean fitness: 548200.1934
# Iter  35 | Best fitness: 14160.9460 | Mean fitness: 628563.4753
# Iter  36 | Best fitness: 14160.9460 | Mean fitness: 689407.0297
# Iter  37 | Best fitness: 14160.9460 | Mean fitness: 862055.8797
# Iter  38 | Best fitness: 14160.9460 | Mean fitness: 625475.9029
# Iter  39 | Best fitness: 14160.9460 | Mean fitness: 549644.1840
# Iter  40 | Best fitness: 14160.9460 | Mean fitness: 643629.5359
# Iter  41 | Best fitness: 14160.9460 | Mean fitness: 672040.9169
# Iter  42 | Best fitness: 14160.9460 | Mean fitness: 549598.2342
# Iter  43 | Best fitness: 14160.9460 | Mean fitness: 732417.7289
# Iter  44 | Best fitness: 14160.9460 | Mean fitness: 536338.3806
# Iter  45 | Best fitness: 14160.9460 | Mean fitness: 700050.1747
# Iter  46 | Best fitness: 14160.9460 | Mean fitness: 742355.7224
# Iter  47 | Best fitness: 14160.9460 | Mean fitness: 634812.7354
# Iter  48 | Best fitness: 14160.9460 | Mean fitness: 507088.3139
# Iter  49 | Best fitness: 14160.9460 | Mean fitness: 567235.6191
# Iter  50 | Best fitness: 14160.9460 | Mean fitness: 695306.9823
# Iter  51 | Best fitness: 14160.9460 | Mean fitness: 601325.9368
# Iter  52 | Best fitness: 14160.9460 | Mean fitness: 425063.6799
# Iter  53 | Best fitness: 14160.9460 | Mean fitness: 493242.2744
# Iter  54 | Best fitness: 14160.9460 | Mean fitness: 642827.7954
# Iter  55 | Best fitness: 14160.9460 | Mean fitness: 650633.7500
# Iter  56 | Best fitness: 14160.9460 | Mean fitness: 437089.4415
# Iter  57 | Best fitness: 14160.9460 | Mean fitness: 669097.1438
# Iter  58 | Best fitness: 14160.9460 | Mean fitness: 475828.3946
# Iter  59 | Best fitness: 14160.9460 | Mean fitness: 571371.2633
# Iter  60 | Best fitness: 14160.9460 | Mean fitness: 646177.4892
# Iter  61 | Best fitness: 14160.9460 | Mean fitness: 587733.0187
# Iter  62 | Best fitness: 14160.9460 | Mean fitness: 609996.6100
# Iter  63 | Best fitness: 14160.9460 | Mean fitness: 664184.2795
# Iter  64 | Best fitness: 14160.9460 | Mean fitness: 581494.0839
# Iter  65 | Best fitness: 14160.9460 | Mean fitness: 630933.2101
# Iter  66 | Best fitness: 14160.9460 | Mean fitness: 483566.2045
# Iter  67 | Best fitness: 14160.9460 | Mean fitness: 571974.3932
# Iter  68 | Best fitness: 14160.9460 | Mean fitness: 585774.5069
# Iter  69 | Best fitness: 14160.9460 | Mean fitness: 630406.9419
# Iter  70 | Best fitness: 14160.9460 | Mean fitness: 730293.8855
# Iter  71 | Best fitness: 14160.9460 | Mean fitness: 698437.4227
# Iter  72 | Best fitness: 14160.9460 | Mean fitness: 511374.8638
# Iter  73 | Best fitness: 14160.9460 | Mean fitness: 543136.4616
# Iter  74 | Best fitness: 14160.9460 | Mean fitness: 594062.6084
# Iter  75 | Best fitness: 14160.9460 | Mean fitness: 615993.8508
# Iter  76 | Best fitness:  2391.7530 | Mean fitness: 556164.0541
# Iter  77 | Best fitness:  2391.7530 | Mean fitness: 442048.1807
# Iter  78 | Best fitness:  2391.7530 | Mean fitness: 494668.6669
# Iter  79 | Best fitness:  2391.7530 | Mean fitness: 540965.3233
# Iter  80 | Best fitness:  2391.7530 | Mean fitness: 683892.0726
# Iter  81 | Best fitness:  2391.7530 | Mean fitness: 713922.1496
# Iter  82 | Best fitness:  2391.7530 | Mean fitness: 704092.9680
# Iter  83 | Best fitness:  2391.7530 | Mean fitness: 629537.1512
# Iter  84 | Best fitness:  2391.7530 | Mean fitness: 613306.1160
# Iter  85 | Best fitness:  2391.7530 | Mean fitness: 636817.8873
# Iter  86 | Best fitness:  2391.7530 | Mean fitness: 586142.4714
# Iter  87 | Best fitness:  2391.7530 | Mean fitness: 534328.8959
# Iter  88 | Best fitness:  2391.7530 | Mean fitness: 595378.3922
# Iter  89 | Best fitness:  2391.7530 | Mean fitness: 451014.4272
# Iter  90 | Best fitness:  2391.7530 | Mean fitness: 483859.1162
# Iter  91 | Best fitness:  2391.7530 | Mean fitness: 427633.0480
# Iter  92 | Best fitness:  2391.7530 | Mean fitness: 512559.1928
# Iter  93 | Best fitness:  2391.7530 | Mean fitness: 518679.1257
# Iter  94 | Best fitness:  2391.7530 | Mean fitness: 545622.1535
# Iter  95 | Best fitness:  2391.7530 | Mean fitness: 661998.8790
# Iter  96 | Best fitness:  2391.7530 | Mean fitness: 448690.7327
# Iter  97 | Best fitness:  2391.7530 | Mean fitness: 598233.8095
# Iter  98 | Best fitness:  2391.7530 | Mean fitness: 872239.0212
# Iter  99 | Best fitness:  2391.7530 | Mean fitness: 558500.0773
# Iter 100 | Best fitness:  2391.7530 | Mean fitness: 622780.5052
# Iter 101 | Best fitness:  2391.7530 | Mean fitness: 672436.8110
# Iter 102 | Best fitness:  2391.7530 | Mean fitness: 612970.5120
# Iter 103 | Best fitness:  2391.7530 | Mean fitness: 452764.1585
# Iter 104 | Best fitness:  2391.7530 | Mean fitness: 466235.9973
# Iter 105 | Best fitness:  2391.7530 | Mean fitness: 855787.5339
# Iter 106 | Best fitness:  2391.7530 | Mean fitness: 518675.0723
# Iter 107 | Best fitness:  2391.7530 | Mean fitness: 690876.0478
# Iter 108 | Best fitness:  2391.7530 | Mean fitness: 363427.8780
# Iter 109 | Best fitness:  2391.7530 | Mean fitness: 748676.0871
# Iter 110 | Best fitness:  2391.7530 | Mean fitness: 723973.2057
# Iter 111 | Best fitness:  2391.7530 | Mean fitness: 609842.6961
# Iter 112 | Best fitness:  2391.7530 | Mean fitness: 542826.3284
# Iter 113 | Best fitness:  2391.7530 | Mean fitness: 597597.6652
# Iter 114 | Best fitness:  2391.7530 | Mean fitness: 610885.9474
# Iter 115 | Best fitness:  2391.7530 | Mean fitness: 550152.6417
# Iter 116 | Best fitness:  2391.7530 | Mean fitness: 577782.1897
# Iter 117 | Best fitness:  2391.7530 | Mean fitness: 781858.1795
# Iter 118 | Best fitness:  2391.7530 | Mean fitness: 621122.2819
# Iter 119 | Best fitness:  2391.7530 | Mean fitness: 716981.2137
# Iter 120 | Best fitness:  2391.7530 | Mean fitness: 623577.4869
# Iter 121 | Best fitness:  2391.7530 | Mean fitness: 603356.0638
# Iter 122 | Best fitness:  2391.7530 | Mean fitness: 579148.7228
# Iter 123 | Best fitness:  2391.7530 | Mean fitness: 465165.4508
# Iter 124 | Best fitness:  2391.7530 | Mean fitness: 455658.1132
# Iter 125 | Best fitness:  2391.7530 | Mean fitness: 489918.2119
# Iter 126 | Best fitness:  2391.7530 | Mean fitness: 796197.3780
# Iter 127 | Best fitness:  2391.7530 | Mean fitness: 697148.9318
# Iter 128 | Best fitness:  2391.7530 | Mean fitness: 639448.5587
# Iter 129 | Best fitness:  2391.7530 | Mean fitness: 546526.5047
# Iter 130 | Best fitness:  2391.7530 | Mean fitness: 467616.3736
# Iter 131 | Best fitness:  2391.7530 | Mean fitness: 374206.4145
# Iter 132 | Best fitness:  2391.7530 | Mean fitness: 538903.7221
# Iter 133 | Best fitness:  2391.7530 | Mean fitness: 620800.8060
# Iter 134 | Best fitness:  2391.7530 | Mean fitness: 607014.0959
# Iter 135 | Best fitness:  2391.7530 | Mean fitness: 628098.2713
# Iter 136 | Best fitness:  2391.7530 | Mean fitness: 558948.6737
# Iter 137 | Best fitness:  2391.7530 | Mean fitness: 615981.6876
# Iter 138 | Best fitness:  2391.7530 | Mean fitness: 618911.5088
# Iter 139 | Best fitness:  2391.7530 | Mean fitness: 445126.5217
# Iter 140 | Best fitness:  2391.7530 | Mean fitness: 598042.3253
# Iter 141 | Best fitness:  2391.7530 | Mean fitness: 433734.8784
# Iter 142 | Best fitness:  2391.7530 | Mean fitness: 474020.1438
# Iter 143 | Best fitness:  2391.7530 | Mean fitness: 478565.8442
# Iter 144 | Best fitness:  2391.7530 | Mean fitness: 674664.4863
# Iter 145 | Best fitness:  2391.7530 | Mean fitness: 433425.5305
# Iter 146 | Best fitness:  2391.7530 | Mean fitness: 708560.2407
# Iter 147 | Best fitness:  2391.7530 | Mean fitness: 680892.4099
# Iter 148 | Best fitness:  2391.7530 | Mean fitness: 575908.2094
# Iter 149 | Best fitness:  2391.7530 | Mean fitness: 616016.5304
# Iter 150 | Best fitness:  2391.7530 | Mean fitness: 513545.8811
# Iter 151 | Best fitness:  2391.7530 | Mean fitness: 606231.7667
# Iter 152 | Best fitness:  2391.7530 | Mean fitness: 538382.6975
# Iter 153 | Best fitness:  2391.7530 | Mean fitness: 601755.7136
# Iter 154 | Best fitness:  2391.7530 | Mean fitness: 453923.0746
# Iter 155 | Best fitness:  2391.7530 | Mean fitness: 598381.6148
# Iter 156 | Best fitness:  2391.7530 | Mean fitness: 485456.0112
# Iter 157 | Best fitness:  2391.7530 | Mean fitness: 664827.7738
# Iter 158 | Best fitness:  2391.7530 | Mean fitness: 639915.2005
# Iter 159 | Best fitness:  2391.7530 | Mean fitness: 608847.3463
# Iter 160 | Best fitness:  2391.7530 | Mean fitness: 533182.1252
# Iter 161 | Best fitness:  2391.7530 | Mean fitness: 495797.0293
# Iter 162 | Best fitness:  2391.7530 | Mean fitness: 515319.5955
# Iter 163 | Best fitness:  2391.7530 | Mean fitness: 612662.6763
# Iter 164 | Best fitness:  2391.7530 | Mean fitness: 505875.2714
# Iter 165 | Best fitness:  2391.7530 | Mean fitness: 594559.9882
# Iter 166 | Best fitness:  2391.7530 | Mean fitness: 514255.0383
# Iter 167 | Best fitness:  2391.7530 | Mean fitness: 586847.7640
# Iter 168 | Best fitness:  2391.7530 | Mean fitness: 575382.8691
# Iter 169 | Best fitness:  2391.7530 | Mean fitness: 513535.8256
# Iter 170 | Best fitness:  2391.7530 | Mean fitness: 495895.8146
# Iter 171 | Best fitness:  2391.7530 | Mean fitness: 586190.4009
# Iter 172 | Best fitness:  2391.7530 | Mean fitness: 598585.9420
# Iter 173 | Best fitness:   478.7966 | Mean fitness: 472926.5278
# Iter 174 | Best fitness:   478.7966 | Mean fitness: 415520.3131
# Iter 175 | Best fitness:   478.7966 | Mean fitness: 506507.6329
# Iter 176 | Best fitness:   478.7966 | Mean fitness: 486303.3311
# Iter 177 | Best fitness:   478.7966 | Mean fitness: 611633.1323
# Iter 178 | Best fitness:   478.7966 | Mean fitness: 689260.4020
# Iter 179 | Best fitness:   478.7966 | Mean fitness: 371206.8786
# Iter 180 | Best fitness:   478.7966 | Mean fitness: 498689.1586
# Iter 181 | Best fitness:   478.7966 | Mean fitness: 426567.1335
# Iter 182 | Best fitness:   478.7966 | Mean fitness: 691406.0011
# Iter 183 | Best fitness:   478.7966 | Mean fitness: 514613.2417
# Iter 184 | Best fitness:   478.7966 | Mean fitness: 546998.6461
# Iter 185 | Best fitness:   478.7966 | Mean fitness: 546965.1840
# Iter 186 | Best fitness:   478.7966 | Mean fitness: 673488.8120
# Iter 187 | Best fitness:   478.7966 | Mean fitness: 548197.0759
# Iter 188 | Best fitness:   469.7825 | Mean fitness: 568681.6533
# Iter 189 | Best fitness:   469.7825 | Mean fitness: 455997.5707
# Iter 190 | Best fitness:   469.7825 | Mean fitness: 658798.1639
# Iter 191 | Best fitness:   469.7825 | Mean fitness: 448028.0844
# Iter 192 | Best fitness:   469.7825 | Mean fitness: 607658.9198
# Iter 193 | Best fitness:   469.7825 | Mean fitness: 638929.3110
# Iter 194 | Best fitness:   469.7825 | Mean fitness: 534866.1942
# Iter 195 | Best fitness:   469.7825 | Mean fitness: 694127.4905
# Iter 196 | Best fitness:   469.7825 | Mean fitness: 612980.0738
# Iter 197 | Best fitness:   469.7825 | Mean fitness: 667275.9097
# Iter 198 | Best fitness:   469.7825 | Mean fitness: 519322.0331
# Iter 199 | Best fitness:   469.7825 | Mean fitness: 397851.9025
# Iter 200 | Best fitness:   469.7825 | Mean fitness: 541844.7925
#
# FINAL BEST ROUTE AND METRICS
# Best fitness (with penalties): 469.782500
# Best route (indices w.r.t all_points where 0 is depot): [0, 4, 6, 1, 5, 7, 10, 8, 12, 3, 11, 9, 2, 0]
# Total route distance (no penalties): 469.782500
# Per-leg distances: [57.391, 11.03, 35.448, 33.198, 54.705, 40.819, 27.237, 21.364, 25.057, 45.613, 49.3, 43.409, 25.21]
